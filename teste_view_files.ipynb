# %%
# %load_ext autoreload
# %autoreload 2

# %%
import ipywidgets
import pandas as pd
import matplotlib.pyplot as plt
import pathlib

# %%
pd.options.display.max_columns = None

# %%
path = ipywidgets.Text(placeholder='Insert csv Path HERE')

# %%
path
# Out:
# Text(value='asdas', placeholder='Insert csv Path HERE')

# %%
df = pd.read_csv(path.value,skiprows=[0,2], na_values=-9999)

# %%
df.head()
# Out:
#                    filename        date   time       DOY  daytime  \
# 0  TOB1_2018-10-17_0000.dat  2018-10-17  00:30  290.0208        0
# 1  TOB1_2018-10-17_0000.dat  2018-10-17  01:00  290.0416        0
# 2  TOB1_2018-10-17_0000.dat  2018-10-17  01:30  290.0624        0
# 3  TOB1_2018-10-17_0000.dat  2018-10-17  02:00  290.0833        0
# 4  TOB1_2018-10-17_0000.dat  2018-10-17  02:30  290.1041        0
#
#    file_records  used_records       Tau  qc_Tau         H  qc_H       LE  \
# 0         36000         36000 -0.017150       2 -13.94970     2  4.89794
# 1         36000         36000 -0.020725       2 -21.69500     2  2.48510
# 2         36000         36000  0.005006       2  -5.74243     2 -2.06854
# 3         36000         36000 -0.008134       2  -8.16365     2 -1.26178
# 4         36000         36000 -0.010252       2  -8.54219     2  1.91615
#
#    qc_LE  co2_flux  qc_co2_flux  h2o_flux  qc_h2o_flux   H_strg   LE_strg  \
# 0    2.0  4.275780            2  0.111130          2.0      NaN       NaN
# 1    2.0  3.365560            2  0.056368          2.0 -2.93628  2.275810
# 2    2.0  0.159573            2 -0.046883          2.0 -7.90282  7.567530
# 3    2.0  2.117550            2 -0.028594          2.0 -1.51489 -0.298543
# 4    2.0  4.442130            2  0.043413          2.0 -2.27867  2.645680
#
#    co2_strg  h2o_strg     co2_v-adv     h2o_v-adv  co2_molar_density  \
# 0       NaN       NaN  7.206930e-11  3.914550e-12            15.8691
# 1 -0.439391  0.051621 -9.473750e-11 -5.196600e-12            15.8297
# 2  2.521380  0.171517 -1.322500e-11 -7.284820e-13            16.1578
# 3  2.626110 -0.006765  5.471870e-11  2.957520e-12            16.4612
# 4  6.108680  0.059941 -1.209350e-10 -6.322300e-12            17.1569
#
#    co2_mole_fraction  co2_mixing_ratio  co2_time_lag  co2_def_timelag  \
# 0            422.822           432.761           0.0                0
# 1            421.507           431.483           0.0                0
# 2            429.034           439.419           0.0                0
# 3            436.870           447.435           0.0                0
# 4            455.087           466.178           0.0                0
#
#    h2o_molar_density  h2o_mole_fraction  h2o_mixing_ratio  h2o_time_lag  \
# 0            861.951            22.9662           23.5061           0.0
# 1            868.300            23.1208           23.6680           0.0
# 2            890.030            23.6328           24.2048           0.0
# 3            889.722            23.6126           24.1837           0.0
# 4            896.943            23.7914           24.3712           0.0
#
#    h2o_def_timelag  sonic_temperature  air_temperature  air_pressure  \
# 4       NaN    NaN    NaN    NaN    NaN    NaN -0.009857  1.04002  -7.79151
#
#      H_scf     un_LE   LE_scf  un_co2_flux  co2_scf  un_h2o_flux  h2o_scf  \
# 0  1.07303  5.973320  1.07421     4.570960  1.07421     0.135530  1.07421
# 1  1.08676  4.581480  1.08803     4.043300  1.08803     0.103920  1.08803
# 2  1.06501 -1.241160  1.06789     0.435752  1.06789    -0.028131  1.06789
# 3  1.06942 -0.228876  1.07142     2.374210  1.07142    -0.005187  1.07142
# 4  1.08105  2.690020  1.08249     4.502290  1.08249     0.060946  1.08249
#
#    spikes_hf  amplitude_resolution_hf  drop_out_hf  absolute_limits_hf  \
# 0  800000099                800000099    800000099           800000099
# 1  800000099                800000099    800000099           800000099
# 2  800000099                800000099    800000099           800000099
# 3  800000099                800000099    800000099           800000099
# 4  800000099                800000099    800000099           800000099
#
#    skewness_kurtosis_hf  skewness_kurtosis_sf  discontinuities_hf  \
# 0             800000099             800000099           899999999
# 1             800000099             800000099           899999999
# 2             800000099             800000099           899999999
# 3             800000099             810100099           899999999
# 4             800000199             800000199           899999999
#
#    discontinuities_sf  timelag_hf  timelag_sf  attack_angle_hf  \
# 0           899999999       89999       89999               89
# 1           899999999       89999       89999               89
# 2           899999999       89999       89999               89
# 3           899999999       89999       89999               89
# 4           899999999       89999       89999               89
#
#    non_steady_wind_hf  u_spikes  v_spikes  w_spikes  ts_spikes  co2_spikes  \
# 0                  89         4         7         0          2          80
# 1                  89         1         8         1         11         128
# 2                  89         1         6         1         11          28
# 3                  89         5         9         9          2          14
# 4                  89        10         6         2         27          60
#
#    h2o_spikes     u_var     v_var     w_var    ts_var   co2_var    h2o_var  \
# 0         158  0.128323  0.211324  0.037886  0.061315  0.010981   12.36550
# 1         125  0.264493  0.229832  0.065277  0.064612  0.012177  143.39600
# 2         103  0.265396  0.108736  0.030962  0.026228  0.014033    2.13508
# 3         162  0.089907  0.169228  0.025552  0.047311  0.025297    4.28848
# 4         247  0.251342  0.123342  0.031510  0.022953  0.028307    6.65227
#
#    w/ts_cov  w/co2_cov  w/h2o_cov
# 0 -0.011587   0.004571   0.135530
# 1 -0.018049   0.004043   0.103920
# 2 -0.005005   0.000436  -0.028131
# 3 -0.006994   0.002374  -0.005187
# 4 -0.007067   0.004502   0.060946

# %%
columns = ipywidgets.SelectMultiple(options=df.columns.to_list(), description='Colunas')

# %%
columns
# Out:
# SelectMultiple(description='Colunas', options=('filename', 'date', 'time', 'DOY', 'daytime', 'file_records', '…

# %%
list(columns.value)
# Out:
# ['time', 'DOY', 'daytime']

# %%
plt.plot(df[list(columns.value)])
# Out:
# [<matplotlib.lines.Line2D at 0x29fb4250fc8>,
#  <matplotlib.lines.Line2D at 0x29fb4250b88>]
