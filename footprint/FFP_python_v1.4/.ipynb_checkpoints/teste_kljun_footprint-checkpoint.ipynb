# %%
# %load_ext autoreload
# %autoreload 2

# %%
from calc_footprint_FFP_adjusted01 import FFP

# %%
a = FFP()

# %%
output = a.output(zm=9., umean=2, h=5000., ol=-1000, sigmav=0.6, ustar=0.3, wind_dir=210,rs= [0.3,0.5,0.9],crop=True, fig=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon

# %%
from matplotlib.path import Path

# %%
# %%timeit
point = Point(-0.5, 0.5)
polygon = Polygon([(0, 0), (0, 1), (1, 1), (1, 0)])
polygon.contains(point)
# print(polygon.contains(point))
# Out:
# 18.9 µs ± 1.08 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
len(output[8])
# Out:
# 3

# %%
plt.plot(output[8][2], output[9][2])

# %%
poly = [(i, j) for i, j in zip(output[8][2], output[9][2])]
poly_shp = Polygon(poly)
poly_mpl = Path(poly)

# %%
x = np.arange(-1000, 1000, 15)
y = np.arange(-1000, 1000, 15)
xx, yy = np.meshgrid(x, y)

# %%
len(x)
# Out:
# 134

# %%
xx, yy = xx.flatten(), yy.flatten()
points = np.vstack((xx,yy)).T

# %%
grid = poly_mpl.contains_points(points)

# %%
mask = grid.reshape(len(x),len(y))

# %%
plt.pcolormesh(x,y,mask)

# %%
from calc_footprint_FFP_climatology_adjusted01 import FFP_climatology

# %%
b = FFP_climatology()

# %%
zmt=20
z0t=0.01
umean=[2.3, 3,5]
ht=[2000., 1800., 1500.]
olt=[-10., -100., -500.]
sigmavt=[0.9, 0.7, 0.3]
ustart=[0.5, 0.3, 0.4]
wind_dirt=[30., 50., 70.]
domaint=[-100., 1000., -100., 1000.]
nxt=1100
rst=[0.1,0.5,0.8]

# %% [markdown]
# (zm=zmt, z0=z0t, umean = None, h=ht, ol=olt, sigmav=sigmavt,
# ustar=ustart, wind_dir=wind_dirt, domain=domaint, nx=nxt, rs=rst,smooth_data=1)

# %%
# b.output(zm=zmt, z0=z0t, umean=None, h=ht, ol=olt, sigmav=sigmavt, ustar=ustart, wind_dir=wind_dirt, domain=domaint, nx=nxt, rs=rst, smooth_data=1, crop=True,fig=True)
teste = b.output(zm=zmt, z0=z0t, umean=umean, h=ht, ol=olt, sigmav=sigmavt, ustar=ustart, wind_dir=wind_dirt, domain=domaint, nx=nxt, rs=rst, smooth_data=1, crop=True,fig=True)
# Out:
# Alert(0017):
#  Only one value of zm passed. Using it for all footprints.
#  Execution continues.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
#  Execution continues.
#
# Calculating footprint  1  of  3
# Calculating footprint  2  of  3
# Calculating footprint  3  of  3
